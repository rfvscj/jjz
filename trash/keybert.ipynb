# %%
import os
os.environ['http_proxy'] = "http://rzcnb:123456@10.20.120.235:8793"
os.environ['https_proxy'] = "http://rzcnb:123456@10.20.120.235:8793"
from zhkeybert import KeyBERT, extract_kws_zh

model = KeyBERT()

model

# %%
extract_kws_zh("山东省青岛市中级人民法院刑事裁定书(2015)青刑执释字第806号罪犯张卫，男，1979年6月27日出生，汉族，山东省平度市人，现服刑于山东省北墅监狱。山东省即墨市人民法院于2011年12月20日作出了(2011)即刑初字第945号刑事判决，认定被告人张卫犯抢劫罪，判处有期徒刑六年，并处罚金人民币7000元。现已执行刑期三年十一个月，罚金于判决前交纳。执行机关山东省北墅监狱于2015年8月3日向本院提请对罪犯张卫假释。山东省青岛市人民检察院向本院提交了检察意见书，认为提请假释程序合法，并同意执行机关提请假释意见。本院依法组成合议庭进行了审理。现已审理终结。经审理查明，假释建议书所述罪犯张卫确有悔改表现，假释后没有再犯罪的危险，有罪犯张卫的评审鉴定表、奖励审批表、罪犯计分考核统计表、调查评估报告等证据证实，经综合审查后，本院予以确认。本院认为，罪犯张卫被判处有期徒刑六年，现已执行原判刑期二分之一以上，服刑期间能够认真遵守监规，接受教育改造，确有悔改表现，没有再犯罪的危险。对报请机关山东省北墅监狱提请假释的意见予以支持。对山东省青岛市人民检察院同意其假释的意见予以采纳。", model, ngram_range=(1, 1), top_n=100)
# Out:
# [('有期徒刑', 0.7863),
#  ('刑事判决', 0.6998),
#  ('假释', 0.7104),
#  ('刑期', 0.7236),
#  ('罪犯', 0.6749),
#  ('监狱', 0.684),
#  ('服刑', 0.6792),
#  ('执释', 0.6789),
#  ('处罚金', 0.6467),
#  ('判处', 0.6425),
#  ('犯罪', 0.613),
#  ('即刑', 0.6069),
#  ('罚金', 0.6038),
#  ('人民法院', 0.5551),
#  ('抢劫罪', 0.5455),
#  ('被告人', 0.5481),
#  ('人民检察院', 0.5325),
#  ('检察', 0.5365),
#  ('依法', 0.4771),
#  ('原判', 0.5016),
#  ('刑事', 0.469),
#  ('审理', 0.4723),
#  ('判决', 0.4642),
#  ('张卫犯', 0.4236),
#  ('十一个月', 0.2602),
#  ('青岛市', 0.3028),
#  ('合法', 0.4386),
#  ('1979', 0.2793),
#  ('青刑', 0.3552),
#  ('监规', 0.3866),
#  ('人民币', 0.3081),
#  ('三年', 0.2483),
#  ('945', 0.2467),
#  ('审批表', 0.3077),
#  ('悔改', 0.3169),
#  ('出生', 0.2538),
#  ('中级', 0.3031),
#  ('六年', 0.2575),
#  ('裁定书', 0.3396),
#  ('年', 0.275),
#  ('评审', 0.3194),
#  ('山东省', 0.2654),
#  ('教育', 0.2125),
#  ('计分', 0.2872),
#  ('合议庭', 0.2872),
#  ('2011', 0.2285),
#  ('危险', 0.2294),
#  ('期间', 0.2618),
#  ('于', 0.2932),
#  ('证据', 0.2122),
#  ('汉族', 0.2696),
# ...
